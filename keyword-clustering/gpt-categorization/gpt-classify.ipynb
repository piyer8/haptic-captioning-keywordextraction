# %%
from openai import OpenAI
import os
import json
from dotenv import load_dotenv
from pathlib import Paths

extracted_answers = []
query_file = "queries.json"


dotenv_path = Path('../../global_environment.env')
load_dotenv(dotenv_path=dotenv_path)
openai_key = os.getenv('OPENAI_KEY')

client = OpenAI(
        api_key=openai_key
)

if(openai_key):
    print('Key loaded successfully')
else:
    print('API Key not found')
# Out:
# Key loaded successfully

# %%
def getRating(keywords):
    keywords_list = '\n'.join(keywords)
    
    response = client.beta.chat.completions.parse(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": "You are an assistant that processes descriptions of haptic feedback and returns json objects"},
                {"role": "user", "content": "Classify the list of keywords and phrases into categories and return a json object containing the categories and a list of respective key words/phrases:\n"+keywords_list},
                ],
        )
    print(response.choices[0].message.content)
    return json.loads(response.choices[0].message.content) # response.choices[0].message.content

def gettags(signalObj):

with open('./all_keywords.json', 'r') as f:
    words = json.load(f)

def save_json(filename, data):
    with open(filename, "w") as f:
        json.dump(data, f, indent=4)

# sensory_categories = getRating(words['sensory_keywords'])
# save_json('./sensory_categories.json', sensory_categories)
#emotional_categories = getRating(words['emotional_keywords'])
#save_json('./emotional_categories.json', emotional_categories)
associative_categories = getRating(words['associative_keywords'])
save_json('./associative_categories.json', associative_categories)
# Out:
# ```json
# {
#   "categories": {
#     "Sounds": [
#       "high pitch",
#       "rock music",
#       "frogs",
#       "human pulse",
#       "waves crashing",
#       "ticking clock",
#       "frog croaking",
#       "drum band",
#       "drumming pattern",
#       "loud ringing",
#       "buzz sound",
#       "soft droplets of water",
#       "beep",
#       "alarm",
#       "scary movie",
#       "music concert",
#       "gameplay",
#       "news",
#       "drum beats",
#       "heavy rain season",
#       "interruptions",
#       "sound of water",
#       "splashing",
#       "water running",
#       "soft vibration",
#       "sound of breeze",
#       "crying",
#       "muffled",
#       "snoring"
#     ],
#     "Haptics": [
#       "vibrating",
#       "vibrating mobile",
#       "vibration pattern",
#       "haptic feedback",
#       "tapping",
#       "vibrating chair",
#       "constant vibration",
#       "subtle vibrations",
#       "unexpected vibrations",
#       "low frequency vibration",
#       "intense vibrations",
#       "vibration form",
#       "vibrational patterns",
#       "vibrating object",
#       "phone vibrates"
#     ],
#     "Music": [
#       "song intro",
#       "musical sensation",
#       "musical rhythm",
#       "bass-heavy pop songs",
#       "EDM music",
#       "electronic music concert",
#       "indie folk song",
#       "pop music",
#       "dj",
#       "booming music"
#     ],
#     "Vehicles": [
#       "2 stroke bike",
#       "motorcycles",
#       "car",
#       "train running",
#       "running machine",
#       "driving motorcycle",
#       "drive mode",
#       "revving a car engine",
#       "engine starts",
#       "vehicle movement"
#     ],
#     "Personal Experiences": [
#       "first phone",
#       "exam hall",
#       "party club",
#       "emergency sirens",
#       "living experience",
#       "chat",
#       "leading to conflict",
#       "waiting period",
#       "relaxed heartbeat",
#       "feeling pricked"
#     ],
#     "Notifications": [
#       "in-app notifications",
#       "phone alarm vibrations",
#       "game notifications",
#       "reminder notifications",
#       "message notifications"
#     ],
#     "Physical Sensations": [
#       "nails",
#       "back pain",
#       "bumps",
#       "heart race",
#       "intense stimulation",
#       "pulses",
#       "numbness",
#       "random sensations",
#       "muscle relaxation"
#     ],
#     "Locations and Environments": [
#       "night club",
#       "school",
#       "apartment",
#       "hospital",
#       "supermarkets",
#       "beach",
#       "driving on the freeway",
#       "cobblestone path",
#       "highways",
#       "medicinal flow"
#     ],
#     "Activities": [
#       "playing Fortnite",
#       "playing Call of Duty",
#       "skating",
#       "school practice",
#       "playing chess",
#       "party DJ",
#       "homework"
#     ],
#     "Sensory Experiences": [
#       "touching",
#       "actions",
#       "emotion",
#       "new experience",
#       "pleasurable chat",
#       "relaxation",
#       "exciting phone alarm",
#       "feeling low",
#       "stressful tasks"
#     ],
#     "Mechanical Sounds": [
#       "engine noise",
#       "moving furniture",
#       "drilling machine",
#       "machine breakdown",
#       "electronic mixer",
#       "electric heater",
#       "broken phones"
#     ],
#     "Events": [
#       "concert night",
#       "emergency room",
#       "dance lessons",
#       "important event",
#       "sessions",
#       "exams"
#     ],
#     "Cues to Action": [
#       "start/stop",
#       "waiting",
#       "calling",
#       "sending",
#       "rev the engine"
#     ],
#     "Miscellaneous": [
#       "daydreaming",
#       "something bad",
#       "verbal commands",
#       "communication devices",
#       "motorbike adventures",
#       "different tasks"
#     ]
#   }
# }
# ```
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 25
#      19         json.dump(data, f, indent=4)
#      21 # sensory_categories = getRating(words['sensory_keywords'])
#      22 # save_json('./sensory_categories.json', sensory_categories)
#      23 #emotional_categories = getRating(words['emotional_keywords'])
#      24 #save_json('./emotional_categories.json', emotional_categories)
# ---> 25 associative_categories = getRating(words['associative_keywords'])
#      26 save_json('./associative_categories.json', associative_categories)
#
# Cell In[6], line 12, in getRating(keywords)
#       4 response = client.beta.chat.completions.parse(
#       5         model="gpt-4o-mini",
#       6         messages=[
#    (...)
#       9             ],
#      10     )
#      11 print(response.choices[0].message.content)
# ---> 12 return json.loads(response.choices[0].message.content)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
