# %%
import json
import numpy as np
import requests
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from collections import defaultdict
import os

CACHE_FILE = "conceptnet_embeddings.json"

def load_cache():
    """ Load cached embeddings if available. """
    if os.path.exists(CACHE_FILE):
        with open(CACHE_FILE, "r") as f:
            return json.load(f)
    return {}

def save_cache(cache):
    with open(CACHE_FILE, "w") as f:
        json.dump(cache, f)

def get_conceptnet_embedding(word):
    """ Fetch word embedding from ConceptNet. """
    url = f"http://api.conceptnet.io/c/en/{word}"
    response = requests.get(url).json()
    print("Fetching embedding for word:", word)
    print(response)
    for edge in response.get("edges", []):
        if 'embedding' in edge['start']:
            return edge['start']['embedding']['vector']
        elif 'embedding' in edge['end']:
            return edge['end']['embedding']['vector']
    
    return None  # Return None if embedding is not found

def get_embeddings(words):
    """ Get embeddings for a list of words, using a cache to reduce API calls. """
    cache = load_cache()
    embeddings = {}

    for word in words:
        word_cleaned = word.lower().replace(" ", "_")

        if word_cleaned in cache:
            embeddings[word] = np.array(cache[word_cleaned])
        else:
            embedding = get_conceptnet_embedding(word_cleaned)
            if embedding is not None:
                embeddings[word] = np.array(embedding)
                cache[word_cleaned] = embedding  # Store in cache

    save_cache(cache)  # Save cache after fetching missing embeddings
    return embeddings

def cluster_keywords(embeddings, n_clusters=3):
    words = list(embeddings.keys())
    vectors = np.array(list(embeddings.values()))
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(vectors)
    
    clustered_words = defaultdict(list)
    for word, label in zip(words, labels):
        clustered_words[label].append(word)
    
    return clustered_words

def plot_clusters(embeddings, clustered_words):
    words = list(embeddings.keys())
    vectors = np.array(list(embeddings.values()))
    
    pca = PCA(n_components=2)
    reduced_vectors = pca.fit_transform(vectors)
    
    plt.figure(figsize=(10, 6))
    
    for label, words in clustered_words.items():
        indices = [words.index(word) for word in words if word in embeddings]
        plt.scatter(reduced_vectors[indices, 0], reduced_vectors[indices, 1], label=f"Cluster {label}")
        for i in indices:
            plt.annotate(words[i], (reduced_vectors[i, 0], reduced_vectors[i, 1]))
    
    plt.legend()
    plt.show()

def main():
    with open("./all_signals.json", "r") as f:
        data = json.load(f)
    
    sensory_keywords = set()
    emotional_keywords = set()
    associative_keywords = set()
    
    for entry in data:
        sensory = (entry["sensory"]["keywords"][0].split(","))
        emotional =(entry["emotional"]["keywords"][0].split(","))
        associative = (entry["associative"]["keywords"][0].split(","))
        for word in sensory:
            sensory_keywords.add(word.strip())
        for word in emotional:
            emotional_keywords.add(word.strip())
        for word in associative:
            associative_keywords.add(word.strip())
    
    all_keywords = list(sensory_keywords)
    
    embeddings = get_embeddings(all_keywords)
    clustered_words = cluster_keywords(embeddings, n_clusters=5)
    plot_clusters(embeddings, clustered_words)
    
    print("Clustered Keywords:")
    for cluster, words in clustered_words.items():
        print(f"Cluster {cluster}: {', '.join(words)}")
    
if __name__ == "__main__":
    main()
# Out:
# Fetching embedding for word: cutting_wood
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/cutting_wood', 'edges': [{'@id': '/a/[/r/UsedFor/,/c/en/saw/,/c/en/cutting_wood/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/cutting_wood', '@type': 'Node', 'label': 'cutting wood', 'language': 'en', 'term': '/c/en/cutting_wood'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/UsedFor', '@type': 'Relation', 'label': 'UsedFor'}, 'sources': [{'@id': '/and/[/s/activity/omcs/commons_manual_entry/,/s/contributor/omcs/bami25/]', '@type': 'Source', 'activity': '/s/activity/omcs/commons_manual_entry', 'contributor': '/s/contributor/omcs/bami25'}, {'@id': '/and/[/s/activity/omcs/commons_manual_entry/,/s/contributor/omcs/digba121/]', '@type': 'Source', 'activity': '/s/activity/omcs/commons_manual_entry', 'contributor': '/s/contributor/omcs/digba121'}, {'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/bluerock/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/bluerock'}, {'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/jeffw/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/jeffw'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/glt/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/glt'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/mason11987/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/mason11987'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/secrgb/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/secrgb'}], 'start': {'@id': '/c/en/saw', '@type': 'Node', 'label': 'saw', 'language': 'en', 'term': '/c/en/saw'}, 'surfaceText': '[[saw]] is for [[cutting wood]]', 'weight': 4.898979485566356}, {'@id': '/a/[/r/CapableOf/,/c/en/lumberjack/,/c/en/cutting_wood/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/cutting_wood', '@type': 'Node', 'label': 'be cutting wood', 'language': 'en', 'term': '/c/en/cutting_wood'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/CapableOf', '@type': 'Relation', 'label': 'CapableOf'}, 'sources': [{'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/alvinkrinst/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/alvinkrinst'}], 'start': {'@id': '/c/en/lumberjack', '@type': 'Node', 'label': 'A lumberjack', 'language': 'en', 'term': '/c/en/lumberjack'}, 'surfaceText': '[[A lumberjack]] can [[be cutting wood]]', 'weight': 1.0}, {'@id': '/a/[/r/CreatedBy/,/c/en/beam/,/c/en/cutting_wood/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/cutting_wood', '@type': 'Node', 'label': 'cutting wood', 'language': 'en', 'term': '/c/en/cutting_wood'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/CreatedBy', '@type': 'Relation', 'label': 'CreatedBy'}, 'sources': [{'@id': '/and/[/s/activity/omcs/commons_manual_entry/,/s/contributor/omcs/suchow/]', '@type': 'Source', 'activity': '/s/activity/omcs/commons_manual_entry', 'contributor': '/s/contributor/omcs/suchow'}], 'start': {'@id': '/c/en/beam', '@type': 'Node', 'label': 'beam', 'language': 'en', 'term': '/c/en/beam'}, 'surfaceText': '[[beam]] is created by [[cutting wood]].', 'weight': 1.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/saw/,/c/en/cutting_wood/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/cutting_wood', '@type': 'Node', 'label': 'cutting wood', 'language': 'en', 'term': '/c/en/cutting_wood'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/s/resource/verbosity', '@type': 'Source', 'contributor': '/s/resource/verbosity'}], 'start': {'@id': '/c/en/saw', '@type': 'Node', 'lab ...
# Fetching embedding for word: siren_sensation
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/siren_sensation', 'edges': [], 'error': {'details': "'/c/en/siren_sensation' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: concert_vibration
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/concert_vibration', 'edges': [], 'error': {'details': "'/c/en/concert_vibration' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: small_breaks
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/small_breaks', 'edges': [], 'error': {'details': "'/c/en/small_breaks' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: head_banging
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/head_banging', 'edges': [{'@id': '/a/[/r/Synonym/,/c/ja/ヘッドバンギング/n/,/c/en/head_banging/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/head_banging', '@type': 'Node', 'label': 'head banging', 'language': 'en', 'term': '/c/en/head_banging'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/ヘッドバンギング/n', '@type': 'Node', 'label': 'ヘッドバンギング', 'language': 'ja', 'sense_label': 'n', 'term': '/c/ja/ヘッドバンギング'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/wall/,/c/en/head_banging/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/head_banging', '@type': 'Node', 'label': 'head banging', 'language': 'en', 'term': '/c/en/head_banging'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/s/resource/verbosity', '@type': 'Source', 'contributor': '/s/resource/verbosity'}], 'start': {'@id': '/c/en/wall', '@type': 'Node', 'label': 'wall', 'language': 'en', 'term': '/c/en/wall'}, 'surfaceText': '[[wall]] is related to [[head banging]]', 'weight': 0.12199999999999989}], 'version': '5.8.1'}
# Fetching embedding for word: fast_submarine
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/fast_submarine', 'edges': [], 'error': {'details': "'/c/en/fast_submarine' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: little_jolt
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/little_jolt', 'edges': [], 'error': {'details': "'/c/en/little_jolt' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: beats_every_2_seconds
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/beats_every_2_seconds', 'edges': [], 'error': {'details': "'/c/en/beats_every_2_seconds' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: fast_wave
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/fast_wave', 'edges': [], 'error': {'details': "'/c/en/fast_wave' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: firm
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/firm', 'edges': [{'@id': '/a/[/r/RelatedTo/,/c/en/company/,/c/en/firm/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/firm', '@type': 'Node', 'label': 'firm', 'language': 'en', 'term': '/c/en/firm'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/split_words/,/s/resource/verbosity/]', '@type': 'Source', 'contributor': '/s/resource/verbosity', 'process': '/s/process/split_words'}, {'@id': '/s/resource/verbosity', '@type': 'Source', 'contributor': '/s/resource/verbosity'}], 'start': {'@id': '/c/en/company', '@type': 'Node', 'label': 'company', 'language': 'en', 'term': '/c/en/company'}, 'surfaceText': '[[company]] is related to [[firm]]', 'weight': 2.5775957790157857}, {'@id': '/a/[/r/RelatedTo/,/c/sh/tvrd/a/,/c/en/firm/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/firm', '@type': 'Node', 'label': 'firm', 'language': 'en', 'term': '/c/en/firm'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/sh/tvrd/a', '@type': 'Node', 'label': 'tvrd', 'language': 'sh', 'sense_label': 'a', 'term': '/c/sh/tvrd'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/泰然/r/,/c/en/firm/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/firm', '@type': 'Node', 'label': 'firm', 'language': 'en', 'term': '/c/en/firm'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/泰然/r', '@type': 'Node', 'label': '泰然', 'language': 'ja', 'sense_label': 'r', 'term': '/c/ja/泰然'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/こりこり/,/c/en/firm/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/firm', '@type': 'Node', 'label': 'firm', 'language': 'en', 'term': '/c/en/firm'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/こりこり', '@type': 'Node', 'label': 'こりこり', 'language': 'ja', 'term': '/c/ja/こりこり'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/RelatedTo/,/c/sh/koncern/n/,/c/en/firm/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/firm', '@type': 'Node', 'label': 'firm', 'language': 'en', 'term': '/c/en/firm'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/sh/koncern/n', '@type': 'Node', 'label': 'koncern', 'language': 'sh', 'sense_label': 'n', 'term': '/c/sh/koncern'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/シャキッと/,/c/en/firm/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/firm', '@type': 'Node', 'label': 'firm', 'language': 'en', 'term': '/c/en/firm'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/シャキッと', '@type': 'Node', 'label': 'シャキッと', 'language': 'ja', 'term': '/c/ja/シャキッと'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/pt/empresas/n/wn/group/,/c/en/firm/n/wn/group/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'e ...
# Fetching embedding for word: on_off
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/on_off', 'edges': [{'@id': '/a/[/r/Synonym/,/c/ja/オンオフ/n/,/c/en/on_off/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/on_off', '@type': 'Node', 'label': 'on off', 'language': 'en', 'term': '/c/en/on_off'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/オンオフ/n', '@type': 'Node', 'label': 'オンオフ', 'language': 'ja', 'sense_label': 'n', 'term': '/c/ja/オンオフ'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/on_off/a/,/c/en/fluctuate/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/fluctuate', '@type': 'Node', 'label': 'fluctuate', 'language': 'en', 'term': '/c/en/fluctuate'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/on_off/a', '@type': 'Node', 'label': 'on off', 'language': 'en', 'sense_label': 'a', 'term': '/c/en/on_off'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/on_off/a/,/c/en/toggle/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/toggle', '@type': 'Node', 'label': 'toggle', 'language': 'en', 'term': '/c/en/toggle'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/on_off/a', '@type': 'Node', 'label': 'on off', 'language': 'en', 'sense_label': 'a', 'term': '/c/en/on_off'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/RelatedTo/,/c/es/apaño/n/,/c/en/on_off/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/on_off', '@type': 'Node', 'label': 'on off', 'language': 'en', 'term': '/c/en/on_off'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/es/apaño/n', '@type': 'Node', 'label': 'apaño', 'language': 'es', 'sense_label': 'n', 'term': '/c/es/apaño'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/on_off/a/,/c/en/on_off_relationship/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/on_off_relationship', '@type': 'Node', 'label': 'on off relationship', 'language': 'en', 'term': '/c/en/on_off_relationship'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/on_off/a', '@type': 'Node', 'label': 'on off', 'language': 'en', 'sense_label': 'a', 'term': '/c/en/on_off'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/Synonym/,/c/en/on_again_off_again/a/,/c/en/on_off/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/on_off', '@type': 'Node', 'label': 'on off', 'language': 'en', 'term': '/c/en/on_off'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/on_again_off ...
# Fetching embedding for word: jerking
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/jerking', 'edges': [{'@id': '/a/[/r/Synonym/,/c/en/jerking/n/wn/act/,/c/en/jerk/n/wn/act/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/jerk/n/wn/act', '@type': 'Node', 'label': 'jerk', 'language': 'en', 'sense_label': 'n, act', 'term': '/c/en/jerk'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/jerking/n/wn/act', '@type': 'Node', 'label': 'jerking', 'language': 'en', 'sense_label': 'n, act', 'term': '/c/en/jerking'}, 'surfaceText': '[[jerking]] is a synonym of [[jerk]]', 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/en/jerking/a/wn/,/c/en/arrhythmic/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/arrhythmic/a/wn', '@type': 'Node', 'label': 'arrhythmic', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/arrhythmic'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/jerking/a/wn', '@type': 'Node', 'label': 'jerking', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/jerking'}, 'surfaceText': '[[jerking]] is a synonym of [[arrhythmic]]', 'weight': 2.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/asterixis/n/,/c/en/jerking/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/jerking', '@type': 'Node', 'label': 'jerking', 'language': 'en', 'term': '/c/en/jerking'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/asterixis/n', '@type': 'Node', 'label': 'asterixis', 'language': 'en', 'sense_label': 'n', 'term': '/c/en/asterixis'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/DerivedFrom/,/c/en/jerkingly/,/c/en/jerking/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/jerking', '@type': 'Node', 'label': 'jerking', 'language': 'en', 'term': '/c/en/jerking'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/DerivedFrom', '@type': 'Relation', 'label': 'DerivedFrom'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/jerkingly', '@type': 'Node', 'label': 'jerkingly', 'language': 'en', 'term': '/c/en/jerkingly'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/RelatedTo/,/c/it/sballottamento/n/,/c/en/jerking/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/jerking', '@type': 'Node', 'label': 'jerking', 'language': 'en', 'term': '/c/en/jerking'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/it/sballottamento/n', '@type': 'Node', 'label': 'sballottamento', 'language': 'it', 'sense_label': 'n', 'term': '/c/it/sballottamento'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/jerky/a/wikt/en_1/,/c/en/jerking/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/jerking', '@type': 'Node', 'label': 'jerking', 'language': 'en', 'term': '/c/en/jerking'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@typ ...
# Fetching embedding for word: constant_feeling
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/constant_feeling', 'edges': [], 'error': {'details': "'/c/en/constant_feeling' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: small_amplitude_burst
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/small_amplitude_burst', 'edges': [], 'error': {'details': "'/c/en/small_amplitude_burst' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: waves
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/waves', 'edges': [{'@id': '/a/[/r/RelatedTo/,/c/en/sound/,/c/en/waves/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/waves', '@type': 'Node', 'label': 'waves', 'language': 'en', 'term': '/c/en/waves'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/split_words/,/s/resource/verbosity/]', '@type': 'Source', 'contributor': '/s/resource/verbosity', 'process': '/s/process/split_words'}, {'@id': '/s/resource/verbosity', '@type': 'Source', 'contributor': '/s/resource/verbosity'}], 'start': {'@id': '/c/en/sound', '@type': 'Node', 'label': 'sound', 'language': 'en', 'term': '/c/en/sound'}, 'surfaceText': '[[sound]] is related to [[waves]]', 'weight': 5.253189507337423}, {'@id': '/a/[/r/AtLocation/,/c/en/waves/,/c/en/ocean/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/ocean', '@type': 'Node', 'label': 'ocean', 'language': 'en', 'term': '/c/en/ocean'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/AtLocation', '@type': 'Relation', 'label': 'AtLocation'}, 'sources': [{'@id': '/and/[/s/activity/omcs/commons2_template/,/s/contributor/omcs/essent/]', '@type': 'Source', 'activity': '/s/activity/omcs/commons2_template', 'contributor': '/s/contributor/omcs/essent'}, {'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/rspeer/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/rspeer'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/essent/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/essent'}], 'start': {'@id': '/c/en/waves', '@type': 'Node', 'label': 'waves', 'language': 'en', 'term': '/c/en/waves'}, 'surfaceText': 'You are likely to find [[waves]] in [[ocean]].', 'weight': 2.82842712474619}, {'@id': '/a/[/r/Synonym/,/c/ja/波浪/n/,/c/en/waves/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/waves', '@type': 'Node', 'label': 'waves', 'language': 'en', 'term': '/c/en/waves'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/波浪/n', '@type': 'Node', 'label': '波浪', 'language': 'ja', 'sense_label': 'n', 'term': '/c/ja/波浪'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/HasPrerequisite/,/c/en/surfing/,/c/en/waves/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/waves', '@type': 'Node', 'label': 'waves', 'language': 'en', 'term': '/c/en/waves'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/HasPrerequisite', '@type': 'Relation', 'label': 'HasPrerequisite'}, 'sources': [{'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/ilk/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/ilk'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/laserjoy/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/laserjoy'}], 'start': {'@id': '/c/en/surfing', '@type': 'Node', 'label': 'surfing', 'language': 'en', 'term': '/c/en/surfing'}, 'surfaceText': '[[surfing]] requires [[waves]]', 'weight': 2.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/current/,/c/en/waves/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/waves', '@type': 'Node', 'label': 'waves', 'language': 'en', 'term': '/c/en/waves'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/split_words/,/s/resource/verbosity/]', '@type': 'Source', 'contributor': '/s/resource/verbosity', 'process': '/s/process/split_words'}, {'@id': '/s/resource/verbosity', '@type': 'Source', 'contribut ...
# Fetching embedding for word: medium_long_buzzes
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/medium_long_buzzes', 'edges': [], 'error': {'details': "'/c/en/medium_long_buzzes' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: animal_heartbeat
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/animal_heartbeat', 'edges': [], 'error': {'details': "'/c/en/animal_heartbeat' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: slightly_bigger_vibration
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/slightly_bigger_vibration', 'edges': [], 'error': {'details': "'/c/en/slightly_bigger_vibration' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: continuous_cycle_of_vibrations
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/continuous_cycle_of_vibrations', 'edges': [], 'error': {'details': "'/c/en/continuous_cycle_of_vibrations' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: fainter_vibration
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/fainter_vibration', 'edges': [], 'error': {'details': "'/c/en/fainter_vibration' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: quick_repeating_loop
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/quick_repeating_loop', 'edges': [], 'error': {'details': "'/c/en/quick_repeating_loop' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: singular
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/singular', 'edges': [{'@id': '/a/[/r/Synonym/,/c/ms/mufrad/a/wn/,/c/en/singular/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/singular/a/wn', '@type': 'Node', 'label': 'singular', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/singular'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/ms/mufrad/a/wn', '@type': 'Node', 'label': 'mufrad', 'language': 'ms', 'sense_label': 'a, wn', 'term': '/c/ms/mufrad'}, 'surfaceText': '[[mufrad]] is a translation of [[singular]]', 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/en/singular/a/wn/,/c/en/remarkable/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/remarkable/a/wn', '@type': 'Node', 'label': 'remarkable', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/remarkable'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/singular/a/wn', '@type': 'Node', 'label': 'singular', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/singular'}, 'surfaceText': '[[singular]] is a synonym of [[remarkable]]', 'weight': 2.0}, {'@id': '/a/[/r/SimilarTo/,/c/en/singular/a/wn/,/c/en/single/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/single/a/wn', '@type': 'Node', 'label': 'single', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/single'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/SimilarTo', '@type': 'Relation', 'label': 'SimilarTo'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/singular/a/wn', '@type': 'Node', 'label': 'singular', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/singular'}, 'surfaceText': '[[singular]] is similar to [[single]]', 'weight': 2.0}, {'@id': '/a/[/r/IsA/,/c/en/singular/n/wn/communication/,/c/en/form/n/wn/linguistics/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/form/n/wn/linguistics', '@type': 'Node', 'label': 'form', 'language': 'en', 'sense_label': 'n, linguistics', 'term': '/c/en/form'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/IsA', '@type': 'Relation', 'label': 'IsA'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/singular/n/wn/communication', '@type': 'Node', 'label': 'singular', 'language': 'en', 'sense_label': 'n, communication', 'term': '/c/en/singular'}, 'surfaceText': '[[singular]] is a type of [[form]]', 'weight': 2.0}, {'@id': '/a/[/r/SimilarTo/,/c/en/individual/a/wn/,/c/en/singular/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/singular/a/wn', '@type': 'Node', 'label': 'singular', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/singular'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/SimilarTo', '@type': 'Relation', 'label': 'SimilarTo'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/individual/a/wn', '@type': 'Node', 'label': 'individual', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/individual'}, 'surfaceText': '[[individual]] is similar to [[singular]]', 'weight': 2.0}, {'@id': '/a/[/r/Antonym/,/c/en/singular/n/,/c/en/plural/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/plural', '@type': 'Node', 'label': 'plural', 'language': 'en', 'term': '/c/en/plural'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Antonym', '@type': 'Relation', 'label': 'Antonym'}, 'sources': [{'@id': '/and/[/s/process/w ...
# Fetching embedding for word: shallow
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/shallow', 'edges': [{'@id': '/a/[/r/DistinctFrom/,/c/en/deep/,/c/en/shallow/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/shallow', '@type': 'Node', 'label': 'shallow', 'language': 'en', 'term': '/c/en/shallow'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/DistinctFrom', '@type': 'Relation', 'label': 'DistinctFrom'}, 'sources': [{'@id': '/s/resource/verbosity', '@type': 'Source', 'contributor': '/s/resource/verbosity'}], 'start': {'@id': '/c/en/deep', '@type': 'Node', 'label': 'deep', 'language': 'en', 'term': '/c/en/deep'}, 'surfaceText': '[[deep]] is not [[shallow]]', 'weight': 2.048414020651099}, {'@id': '/a/[/r/SimilarTo/,/c/en/fordable/a/wn/,/c/en/shallow/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/shallow/a/wn', '@type': 'Node', 'label': 'shallow', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/shallow'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/SimilarTo', '@type': 'Relation', 'label': 'SimilarTo'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/fordable/a/wn', '@type': 'Node', 'label': 'fordable', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/fordable'}, 'surfaceText': '[[fordable]] is similar to [[shallow]]', 'weight': 2.0}, {'@id': '/a/[/r/SimilarTo/,/c/en/neritic/a/wn/,/c/en/shallow/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/shallow/a/wn', '@type': 'Node', 'label': 'shallow', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/shallow'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/SimilarTo', '@type': 'Relation', 'label': 'SimilarTo'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/neritic/a/wn', '@type': 'Node', 'label': 'neritic', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/neritic'}, 'surfaceText': '[[neritic]] is similar to [[shallow]]', 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/薄っぺら/a/wn/,/c/en/shallow/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/shallow/a/wn', '@type': 'Node', 'label': 'shallow', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/shallow'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/ja/薄っぺら/a/wn', '@type': 'Node', 'label': '薄っぺら', 'language': 'ja', 'sense_label': 'a, wn', 'term': '/c/ja/薄っぺら'}, 'surfaceText': '[[薄っぺら]] is a translation of [[shallow]]', 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/no/lav/a/wn/,/c/en/shallow/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/shallow/a/wn', '@type': 'Node', 'label': 'shallow', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/shallow'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/no/lav/a/wn', '@type': 'Node', 'label': 'lav', 'language': 'no', 'sense_label': 'a, wn', 'term': '/c/no/lav'}, 'surfaceText': '[[lav]] is a translation of [[shallow]]', 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/th/ตื้นเขิน/v/wn/change/,/c/en/shallow/v/wn/change/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/shallow/v/wn/change', '@type': 'Node', 'label': 'shallow', 'language': 'en', 'sense_label': 'v, change', 'term': '/c/en/shallow'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/th/ตื้นเขิน/v/wn/change', '@ty ...
# Fetching embedding for word: thumping
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/thumping', 'edges': [{'@id': '/a/[/r/Synonym/,/c/ja/バクバク/n/,/c/en/thumping/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/thumping', '@type': 'Node', 'label': 'thumping', 'language': 'en', 'term': '/c/en/thumping'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/バクバク/n', '@type': 'Node', 'label': 'バクバク', 'language': 'ja', 'sense_label': 'n', 'term': '/c/ja/バクバク'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/ばくばく/n/,/c/en/thumping/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/thumping', '@type': 'Node', 'label': 'thumping', 'language': 'en', 'term': '/c/en/thumping'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/ばくばく/n', '@type': 'Node', 'label': 'ばくばく', 'language': 'ja', 'sense_label': 'n', 'term': '/c/ja/ばくばく'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/ゴツンゴツン/r/,/c/en/thumping/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/thumping', '@type': 'Node', 'label': 'thumping', 'language': 'en', 'term': '/c/en/thumping'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/ゴツンゴツン/r', '@type': 'Node', 'label': 'ゴツンゴツン', 'language': 'ja', 'sense_label': 'r', 'term': '/c/ja/ゴツンゴツン'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/en/thumping/n/wn/event/,/c/en/thump/n/wn/event/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/thump/n/wn/event', '@type': 'Node', 'label': 'thump', 'language': 'en', 'sense_label': 'n, event', 'term': '/c/en/thump'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/thumping/n/wn/event', '@type': 'Node', 'label': 'thumping', 'language': 'en', 'sense_label': 'n, event', 'term': '/c/en/thumping'}, 'surfaceText': '[[thumping]] is a synonym of [[thump]]', 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/en/thumping/a/wn/,/c/en/humongous/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/humongous/a/wn', '@type': 'Node', 'label': 'humongous', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/humongous'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/thumping/a/wn', '@type': 'Node', 'label': 'thumping', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/thumping'}, 'surfaceText': '[[thumping]] is a synonym of [[humongous]]', 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/どくん/n/,/c/en/thumping/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/en/thumping', '@type': 'Node', 'label': 'thumping', 'language': 'en', 'term': '/c/en/thumping'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/jmdict/1.07', '@type': 'Source', 'contributor': '/s/resource/jmdict/1.07'}], 'start': {'@id': '/c/ja/どくん/n', '@type': 'Node', 'label': 'どくん', 'language': 'ja', 'sense_label': 'n', 'term': '/c/ja/どくん'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/ja/ドックン/n/,/c/en/thumping/]', '@type': 'Edge', 'dataset': '/d/jmdict', 'end': {'@id': '/c/e ...
# Fetching embedding for word: running
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/running', 'edges': [{'@id': '/a/[/r/HasPrerequisite/,/c/en/running/,/c/en/legs/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/legs', '@type': 'Node', 'label': 'legs', 'language': 'en', 'term': '/c/en/legs'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/HasPrerequisite', '@type': 'Relation', 'label': 'HasPrerequisite'}, 'sources': [{'@id': '/and/[/s/activity/omcs/commons2_template/,/s/contributor/omcs/ricardo_andres_guzman/]', '@type': 'Source', 'activity': '/s/activity/omcs/commons2_template', 'contributor': '/s/contributor/omcs/ricardo_andres_guzman'}, {'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/gary/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/gary'}, {'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/pooua/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/pooua'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/browni/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/browni'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/pooua/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/pooua'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/razzbaronz/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/razzbaronz'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/ricardo_andres_guzman/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/ricardo_andres_guzman'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/zenkatz/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/zenkatz'}], 'start': {'@id': '/c/en/running', '@type': 'Node', 'label': 'running', 'language': 'en', 'term': '/c/en/running'}, 'surfaceText': '[[running]] requires [[legs]]', 'weight': 4.898979485566356}, {'@id': '/a/[/r/HasSubevent/,/c/en/playing_sports/,/c/en/running/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/running', '@type': 'Node', 'label': 'running', 'language': 'en', 'term': '/c/en/running'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/HasSubevent', '@type': 'Relation', 'label': 'HasSubevent'}, 'sources': [{'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/kaoruchan/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/kaoruchan'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/glenbrowning/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/glenbrowning'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/guru1/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/guru1'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/kurt_woloch/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/kurt_woloch'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/nlhelper/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/nlhelper'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/rogerhall/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/rogerhall'}], 'start': {'@id': '/c/en/playing_sports', '@type': 'Node', 'label': 'playing sports', 'language': 'en', 'term': '/c/en/playing_sports'}, 'surfaceText': 'Something you might do while [[playing sports]] is [[running]]', 'weight': 4.47213595499958}, {'@id': '/a/[/r/RelatedTo/,/c/en/race/,/c/en/running/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/r ...
# Fetching embedding for word: low_amplitude
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/low_amplitude', 'edges': [], 'error': {'details': "'/c/en/low_amplitude' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: small_beep
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/small_beep', 'edges': [], 'error': {'details': "'/c/en/small_beep' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: vibration_pattern
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/vibration_pattern', 'edges': [], 'error': {'details': "'/c/en/vibration_pattern' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: chest
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/chest', 'edges': [{'@id': '/a/[/r/UsedFor/,/c/en/chest/,/c/en/storing_things_in/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/storing_things_in', '@type': 'Node', 'label': 'storing things in', 'language': 'en', 'term': '/c/en/storing_things_in'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/UsedFor', '@type': 'Relation', 'label': 'UsedFor'}, 'sources': [{'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/kinchin/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/kinchin'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/azulatigrada/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/azulatigrada'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/junebug/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/junebug'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/odin/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/odin'}], 'start': {'@id': '/c/en/chest', '@type': 'Node', 'label': 'a chest', 'language': 'en', 'term': '/c/en/chest'}, 'surfaceText': '[[a chest]] is for [[storing things in]]', 'weight': 3.4641016151377544}, {'@id': '/a/[/r/AtLocation/,/c/en/chest/,/c/en/bedroom/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/bedroom', '@type': 'Node', 'label': 'a bedroom', 'language': 'en', 'term': '/c/en/bedroom'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/AtLocation', '@type': 'Relation', 'label': 'AtLocation'}, 'sources': [{'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/kacjf73/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/kacjf73'}, {'@id': '/and/[/s/activity/omcs/omcs1_possibly_free_text/,/s/contributor/omcs/smallfish/]', '@type': 'Source', 'activity': '/s/activity/omcs/omcs1_possibly_free_text', 'contributor': '/s/contributor/omcs/smallfish'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/kacjf73/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/kacjf73'}], 'start': {'@id': '/c/en/chest', '@type': 'Node', 'label': 'a chest', 'language': 'en', 'term': '/c/en/chest'}, 'surfaceText': 'You are likely to find [[a chest]] in [[a bedroom]]', 'weight': 2.82842712474619}, {'@id': '/a/[/r/IsA/,/c/en/chest/,/c/en/place_to_store_jewelry/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/place_to_store_jewelry', '@type': 'Node', 'label': 'a place to store jewelry', 'language': 'en', 'term': '/c/en/place_to_store_jewelry'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/IsA', '@type': 'Relation', 'label': 'IsA'}, 'sources': [{'@id': '/and/[/s/activity/omcs/is_a_cleanup/,/s/contributor/omcs/dragonjools/]', '@type': 'Source', 'activity': '/s/activity/omcs/is_a_cleanup', 'contributor': '/s/contributor/omcs/dragonjools'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/browni/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/browni'}, {'@id': '/and/[/s/activity/omcs/vote/,/s/contributor/omcs/phyxis/]', '@type': 'Source', 'activity': '/s/activity/omcs/vote', 'contributor': '/s/contributor/omcs/phyxis'}], 'start': {'@id': '/c/en/chest', '@type': 'Node', 'label': 'a chest', 'language': 'en', 'term': '/c/en/chest'}, 'surfaceText': '[[a chest]] is [[a place to store jewelry]]', 'weight': 2.82842712474619}, {'@id': '/a/[/r/UsedFor/,/c/en/chest/,/c/en/storing_things/]', '@type': 'Edge', 'dataset': '/d/conceptnet/4/en', 'end': {'@id': '/c/en/storing_things', '@type': 'Node', 'label': 'storing things', 'language': 'en', 'term': '/c/en/storing_things'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/UsedFor', '@type': 'Relation' ...
# Fetching embedding for word: fast_sensation
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/fast_sensation', 'edges': [], 'error': {'details': "'/c/en/fast_sensation' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: regular_frequency
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/regular_frequency', 'edges': [], 'error': {'details': "'/c/en/regular_frequency' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: wave-like
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/wave-like', 'edges': [], 'error': {'details': "'/c/en/wave-like' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: slow_continuous_vibrations
# ...
# Fetching embedding for word: no_rhythm
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/no_rhythm', 'edges': [], 'error': {'details': "'/c/en/no_rhythm' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: long_medium_sensation
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/long_medium_sensation', 'edges': [], 'error': {'details': "'/c/en/long_medium_sensation' is not a node in ConceptNet.", 'status': 404}, 'version': '5.8.1'}
# Fetching embedding for word: rhythmic
# {'@context': ['http://api.conceptnet.io/ld/conceptnet5.7/context.ld.json'], '@id': '/c/en/rhythmic', 'edges': [{'@id': '/a/[/r/RelatedTo/,/c/en/dance/,/c/en/rhythmic/]', '@type': 'Edge', 'dataset': '/d/verbosity', 'end': {'@id': '/c/en/rhythmic', '@type': 'Node', 'label': 'rhythmic', 'language': 'en', 'term': '/c/en/rhythmic'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/split_words/,/s/resource/verbosity/]', '@type': 'Source', 'contributor': '/s/resource/verbosity', 'process': '/s/process/split_words'}, {'@id': '/s/resource/verbosity', '@type': 'Source', 'contributor': '/s/resource/verbosity'}], 'start': {'@id': '/c/en/dance', '@type': 'Node', 'label': 'dance', 'language': 'en', 'term': '/c/en/dance'}, 'surfaceText': '[[dance]] is related to [[rhythmic]]', 'weight': 2.6884940022250374}, {'@id': '/a/[/r/RelatedTo/,/c/sh/ritmički/a/,/c/en/rhythmic/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/rhythmic', '@type': 'Node', 'label': 'rhythmic', 'language': 'en', 'term': '/c/en/rhythmic'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/sh/ritmički/a', '@type': 'Node', 'label': 'ritmički', 'language': 'sh', 'sense_label': 'a', 'term': '/c/sh/ritmički'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/en/rhythmic/a/wn/,/c/en/rhythmical/a/wn/]', '@type': 'Edge', 'dataset': '/d/wordnet/3.1', 'end': {'@id': '/c/en/rhythmical/a/wn', '@type': 'Node', 'label': 'rhythmical', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/rhythmical'}, 'license': 'cc:by/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/s/resource/wordnet/rdf/3.1', '@type': 'Source', 'contributor': '/s/resource/wordnet/rdf/3.1'}], 'start': {'@id': '/c/en/rhythmic/a/wn', '@type': 'Node', 'label': 'rhythmic', 'language': 'en', 'sense_label': 'a, wn', 'term': '/c/en/rhythmic'}, 'surfaceText': '[[rhythmic]] is a synonym of [[rhythmical]]', 'weight': 2.0}, {'@id': '/a/[/r/RelatedTo/,/c/en/rhythmic/a/,/c/en/rhythm/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/en/rhythm', '@type': 'Node', 'label': 'rhythm', 'language': 'en', 'term': '/c/en/rhythm'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/RelatedTo', '@type': 'Relation', 'label': 'RelatedTo'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}, {'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/fr/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/fr', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/rhythmic/a', '@type': 'Node', 'label': 'rhythmic', 'language': 'en', 'sense_label': 'a', 'term': '/c/en/rhythmic'}, 'surfaceText': None, 'weight': 2.0}, {'@id': '/a/[/r/Synonym/,/c/en/rhythmic/a/,/c/pt/rítmico/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/pt/rítmico', '@type': 'Node', 'label': 'rítmico', 'language': 'pt', 'term': '/c/pt/rítmico'}, 'license': 'cc:by-sa/4.0', 'rel': {'@id': '/r/Synonym', '@type': 'Relation', 'label': 'Synonym'}, 'sources': [{'@id': '/and/[/s/process/wikiparsec/2/,/s/resource/wiktionary/en/]', '@type': 'Source', 'contributor': '/s/resource/wiktionary/en', 'process': '/s/process/wikiparsec/2'}], 'start': {'@id': '/c/en/rhythmic/a', '@type': 'Node', 'label': 'rhythmic', 'language': 'en', 'sense_label': 'a', 'term': '/c/en/rhythmic'}, 'surfaceText': None, 'weight': 1.0}, {'@id': '/a/[/r/Synonym/,/c/en/rhythmic/a/,/c/cy/rhythmig/]', '@type': 'Edge', 'dataset': '/d/wiktionary/en', 'end': {'@id': '/c/cy/rhythmig', '@type': 'Node', 'label': 'r ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 117
#     114         print(f"Cluster {cluster}: {', '.join(words)}")
#     116 if __name__ == "__main__":
# --> 117     main()
#
# Cell In[16], line 108, in main()
#     104         associative_keywords.add(word.strip())
#     106 all_keywords = list(sensory_keywords)
# --> 108 embeddings = get_embeddings(all_keywords)
#     109 clustered_words = cluster_keywords(embeddings, n_clusters=5)
#     110 plot_clusters(embeddings, clustered_words)
#
# Cell In[16], line 49, in get_embeddings(words)
#      47     embeddings[word] = np.array(cache[word_cleaned])
#      48 else:
# ---> 49     embedding = get_conceptnet_embedding(word_cleaned)
#      50     if embedding is not None:
#      51         embeddings[word] = np.array(embedding)
#
# Cell In[16], line 27, in get_conceptnet_embedding(word)
#      25 """ Fetch word embedding from ConceptNet. """
#      26 url = f"http://api.conceptnet.io/c/en/{word}"
# ---> 27 response = requests.get(url).json()
#      28 print("Fetching embedding for word:", word)
#      29 print(response)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#     509 except BrokenPipeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:398, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     396 for header, value in headers.items():
#     397     self.putheader(header, value)
# --> 398 self.endheaders()
#     400 # If we're given a body we start sending that in chunks.
#     401 if chunks is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1329 else:
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1089 msg = b"\r\n".join(self._buffer)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#    1096     if hasattr(message_body, 'read'):
#    1097         # Let file-like take precedence over byte-like.  This
#    1098         # is needed to allow the current position of mmap'ed
#    1099         # files to be taken into account.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1035, in HTTPConnection.send(self, data)
#    1033 if self.sock is None:
#    1034     if self.auto_open:
# -> 1035         self.connect()
#    1036     else:
#    1037         raise NotConnected()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:236, in HTTPConnection.connect(self)
#     235 def connect(self) -> None:
# --> 236     self.sock = self._new_conn()
#     237     if self._tunnel_host:
#     238         # If we're tunneling it means we're connected to our proxy.
#     239         self._has_connected_to_proxy = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:
